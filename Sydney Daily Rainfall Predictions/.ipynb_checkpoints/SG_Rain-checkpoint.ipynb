# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
sg_rain=pd.read_csv('./datasets/combined_csv.csv', encoding= 'unicode_escape')

# %%
sg_rain.dtypes
# Out:
# Station                          object
# Year                              int64
# Month                             int64
# Day                               int64
# Daily Rainfall Total (mm)        object
# Highest 30 Min Rainfall (mm)     object
# Highest 60 Min Rainfall (mm)     object
# Highest 120 Min Rainfall (mm)    object
# Mean Temperature (Â°C)           object
# Maximum Temperature (Â°C)        object
# Minimum Temperature (Â°C)        object
# Mean Wind Speed (km/h)           object
# Max Wind Speed (km/h)            object
# dtype: object

# %%
col= sg_rain.columns.tolist()
col = col[4:]

# %%
for i in col:
    sg_rain[i].replace({'Â\x97': None}, inplace=True)

# %%
sg_rain.dropna(inplace=True)
sg_rain[col]=sg_rain[col].astype(float)

# %%
sg_rain.dtypes
# Out:
# Station                           object
# Year                               int64
# Month                              int64
# Day                                int64
# Daily Rainfall Total (mm)        float64
# Highest 30 Min Rainfall (mm)     float64
# Highest 60 Min Rainfall (mm)     float64
# Highest 120 Min Rainfall (mm)    float64
# Mean Temperature (Â°C)           float64
# Maximum Temperature (Â°C)        float64
# Minimum Temperature (Â°C)        float64
# Mean Wind Speed (km/h)           float64
# Max Wind Speed (km/h)            float64
# dtype: object

# %%
sg_rain.reset_index(drop=True)
# Out:
#              Station  Year  Month  Day  Daily Rainfall Total (mm)  \
# 0          Admiralty  2018      1    5                        5.0
# 1          Admiralty  2018      1    6                        0.0
# 2          Admiralty  2018      1    7                        2.4
# 3          Admiralty  2018      1    8                       48.0
# 4          Admiralty  2018      1    9                        7.2
# ...              ...   ...    ...  ...                        ...
# 6941  Sentosa Island  2019     12    6                        0.0
# 6942  Sentosa Island  2019     12    7                        0.0
# 6943  Sentosa Island  2019     12   13                       39.0
# 6944  Sentosa Island  2019     12   14                       27.2
# 6945  Sentosa Island  2019     12   20                        0.0
#
#       Highest 30 Min Rainfall (mm)  Highest 60 Min Rainfall (mm)  \
# 0                              2.0                           3.6
# ...

# %%
num_only = sg_rain.columns.tolist()
num_only=num_only[1:]

# %%
sns.pairplot(sg_rain)
